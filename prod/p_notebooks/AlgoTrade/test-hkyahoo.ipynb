# %% [markdown]
# # roll up yearly

# %% [markdown]
# ### Class HKStock

# %%
# %matplotlib notebook

from HKYahoo import HKYahoo

# %%
import pandas as pd
import numpy as np

df = HKYahoo('0823.HK')
#print df.yearly
#print df.monthly
print df.weekly
#print df.daily
# Out:
#               Open    High     Low   Close       Volume  Adj Close  Count
# week_start
# 2007-11-05  16.959  17.154  16.647  16.803   37127438.0     10.354      4
# 2007-11-12  16.588  16.959  16.393  16.666   41601026.0     10.270      5
# 2007-11-19  16.744  16.881  16.295  16.510   50594523.0     10.174      5
# 2007-11-26  16.588  16.842  16.100  16.530   37523740.0     10.411      5
# 2007-12-03  16.490  17.583  16.471  17.056   67522768.0     10.743      5
# 2007-12-10  16.842  17.174  16.627  16.998   48420449.0     10.706      5
# 2007-12-17  16.783  17.018  16.510  16.588   45728324.0     10.448      5
# 2007-12-24  16.510  16.705  16.276  16.295   22847047.0     10.264      3
# 2007-12-31  16.276  16.744  16.198  16.569   34187693.0     10.436      4
# 2008-01-07  16.530  17.525  16.413  17.505  101409515.0     11.026      5
# 2008-01-14  17.759  19.398  17.486  19.184  199461019.0     12.083      5
# ...
